# %% [markdown]
# # Assignment2
#
#
# For the coding part of the homework, you will learn one of the manifold packages, ```geomstats```.
#
# First, you will need to build an environment containing the below packages, and open this jupyter notebook.
#
# ```pip install geomstats
# pip install matplotlib
# pip install numpy```

# %%
import matplotlib
import matplotlib.image as mpimg
import matplotlib.pyplot as plt

import geomstats.visualization as visualization

visualization.tutorial_matplotlib()
import geomstats.backend as gs
import geomstats.visualization as visualization

from geomstats.learning.frechet_mean import FrechetMean
from geomstats.learning.pca import TangentPCA
# Out:
# INFO: Using numpy backend

# %% [markdown]
# ### 1. Working with non-euclidean manifold

# %%
from geomstats.geometry.hypersphere import Hypersphere

dim=2
n_samples = 100
sphere = Hypersphere(dim=dim)
data = sphere.random_von_mises_fisher(kappa=10, n_samples=n_samples)

# %%
# %matplotlib inline

fig = plt.figure(figsize=(8, 8))
ax = fig.add_subplot(111, projection='3d')

visualization.plot(
    data, ax=ax, space='S2', label='Point', s=80)

# %% [markdown]
# ## 1. K-Medoids

# %%
def k_medoids(data, k=2):
    ## TODO
    raise NotImplementedError()

# %% [markdown]
# #### Check your implementation with the sphere data, and visualize your results

# %%
for i in [2,3,4,5]:
    medoids = k_medoids(data, k=i)
    ## TODO: visualization
    raise NotImplementedError()

# %% [markdown]
# ## 3. Riemanian Sampling

# %%
def sampling(manifold):
    # TODO
    pass

# %% [markdown]
# #### Check your implementation with a torus manifold in the homework handout, and visualize your results

# %%
# TODO
torus = None
samples = sampling(torus)
# TODO visualization
raise NotImplementedError()

# %% [markdown]
# ## 4. Riemannian Langevin Diffusion to Sample on Stiefel Manifolds

# %%
stiefel = None

# %%
def langevin_sampler(manifold):
    raise NotImplementedError()

# %%
data = sampler(stiefel)
## TODO: visualization
raise NotImplementedError()

# %%
## TODO initialize your sphere with stiefel Manifold
sphere_stiefel = None
data = sampler(sphere_stiefel)
# TODO visualization
raise NotImplementedError()
